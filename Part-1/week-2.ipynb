# %%
import numpy as np
import time

# %% [markdown]
# ## Vectorization vs Looping

# %%
def my_dot(a, b):
    x = 0
    for i in range(len(a)):
        x = x + a[i]*b[i]
    return x

# %%
a = np.random.rand(10000000)
b = np.random.rand(10000000)

tic = time.time()
c = np.dot(a, b)
toc = time.time()

print(f"np.dot(a, b) = {c:.4f}")
print(f"Vectorized version duration: {1000*(toc-tic):.4f} ms")

tic = time.time()
c = my_dot(a, b)
toc = time.time()

print(f"my_dot(a, b) = {c:.4f}")
print(f"Loop version duration: {1000*(toc-tic):.4f} ms")
# Out:
# np.dot(a, b) = 2500416.0603
# Vectorized version duration: 3.7394 ms
# my_dot(a, b) = 2500416.0603
# Loop version duration: 2383.5065 ms
