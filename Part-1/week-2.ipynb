# %%
import numpy as np
import time

# %% [markdown]
# ## Vectorization vs Looping

# %%
def my_dot(a, b):
    x = 0
    for i in range(len(a)):
        x = x + a[i]*b[i]
    return x

# %%
a = np.random.rand(10000000)
b = np.random.rand(10000000)

tic = time.time()
c = np.dot(a, b)
toc = time.time()

print(f"np.dot(a, b) = {c:.4f}")
print(f"Vectorized version duration: {1000*(toc-tic):.4f} ms")

tic = time.time()
c = my_dot(a, b)
toc = time.time()

print(f"my_dot(a, b) = {c:.4f}")
print(f"Loop version duration: {1000*(toc-tic):.4f} ms")
# Out:
# np.dot(a, b) = 2499781.1118
# Vectorized version duration: 4.2078 ms
# my_dot(a, b) = 2499781.1118
# Loop version duration: 1399.3008 ms
